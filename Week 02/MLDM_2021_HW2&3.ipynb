# %% [markdown]
# ## Please, fill in before you start:

# %% [markdown]
# First Name: Majid
#
# Last Name: Sohrabi
#
# Group: ISSA (Data Science)

# %% [markdown]
# #### Linear Regression and Logistic Regression assigments are stacked, so the deadline for this homework is 10.10.21

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1 (3 points)

# %% [markdown]
# Consider the following toy dataset:

# %%
true_function = lambda x: 3.25 * x - 1.47
noize_function = lambda x: (
    np.random.normal(size=len(x)) * 4. +
    np.where(
        x < 15,
        0.,
        -60 + np.random.normal(size=len(x)) * 10
    ) * (np.random.uniform(size=len(x)) < 0.4).astype(int)
)
limits = (-4., 20.)

def generate_dataset(N=300):
  x = np.random.uniform(*limits, size=N)
  y = true_function(x) + noize_function(x)

  return x[:,None], y

X, y = generate_dataset()

x = np.linspace(*limits, 101)
plt.plot(x, true_function(x), c='black', label='True dependence')
plt.scatter(X, y, s=10, label='Data with noise and outliers')
plt.legend();

# %% [markdown]
# Implement a linear model $\hat y(x|w) = w_1\cdot x + w_0$ with MAE loss:
# $$\text{MAE}(w) = \frac{1}{N}\sum_{i=1}^N\left|y_i - \hat y(x_i|w)\right|,$$
# using gradient descent optimization in `numpy`.
#
# *Hint: introduce a constant feature to account for the bias term to make the formulas simpler.*
#
# Plot the learning curve and the final fit. Also, fit the same data with `sklearn`'s `LinearRegression`, and compare the two fits on the same plot. What do you observe? Write a short comment.

# %%
def myLinearRegression():
    # define teta 
    t0 = np.random.random()
    t1 = np.random.random()    
    iterations = 1000
    alpha = 0.0001
    error = []
    # mean loop
    for it in range(0,iterations):                 
        ## calc gradiant        
        p = t1 * X  + t0 
        p = np.reshape(p,p.shape[0])
        ## update teta   
        t0 -= alpha * sum(p - y) / len(y)
        t1 -= alpha * sum((p - y) * np.reshape(X,X.shape[0])) / len(y)                                
        p = t1 * X  + t0            
        p = np.reshape(p,p.shape[0])
        e = abs(p - y)        
        error.append(sum(e)/ len(y))        
        print(it, end=", error\r")
    return t0, t1, error

t0, t1, error = myLinearRegression()
plt.plot(error)
plt.show()
plt.plot(X, X * t1 + t0, '.r')
plt.scatter(X, y, marker=".", color="b")

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression().fit(X,y)
p = lr.predict(X)
plt.plot(X, X * t1 + t0, '.r')
plt.plot(X, p, '.k')
plt.scatter(X, y, marker=".", color="b")
plt.legend(['our method', 'sklearn'])

# %% [markdown]
# ## Task 2 (2 points + 1 bonus point + 1 super-bonus point)

# %% [markdown]
# (Titanic data again)
#
# Build a model with `sklearn`'s `LogisticRegression` to get the accuracy of at least 0.80 (0.82 for the bonus point, 0.85 for the super-bonus point) on the test set.
#
# Some (optional) suggestions:
# - Add new features (e.g. missing value indicator columns)
# - Fill missing values
# - Encode categorical features (e.g. one-hot encoding)
# - Scale the features (e.g. with standard or robust scaler)
# - Think of other ways of preprocessing the features (e.g. `Fare` $\to$ `log(Fare)`)
# - Try adding polynomial features

# %%
# !wget https://raw.githubusercontent.com/HSE-LAMBDA/MLDM-2021/main/01-intro/train.csv
# Out:
# --2021-10-11 00:45:43--  https://raw.githubusercontent.com/HSE-LAMBDA/MLDM-2021/main/01-intro/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘train.csv.1’
#
# train.csv.1         100%[===================>]  58.89K  --.-KB/s    in 0.01s
#
# 2021-10-11 00:45:43 (5.23 MB/s) - ‘train.csv.1’ saved [60302/60302]

# %%
import pandas as pd
data = pd.read_csv("train.csv", index_col='PassengerId')
data.head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# #### About the data
# Here's some of the columns
# * Name - a string with person's full name
# * Survived - 1 if a person survived the shipwreck, 0 otherwise.
# * Pclass - passenger class. Pclass == 3 is cheap'n'cheerful, Pclass == 1 is for moneybags.
# * Sex - a person's gender
# * Age - age in years, if available
# * SibSp - number of siblings on a ship
# * Parch - number of parents on a ship
# * Fare - ticket cost
# * Embarked - port where the passenger embarked
#  * C = Cherbourg; Q = Queenstown; S = Southampton

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler, RobustScaler, PolynomialFeatures, OneHotEncoder
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

def feature_selection_and_preprocessing(dataset):
  # <YOUR CODE>
  # E.g.:    
  temp_features = dataset[["Fare", "SibSp", "Parch", "Sex", "Pclass", "Age","Embarked"]].copy()
  temp_features['Sex'] = temp_features['Sex'].map({'male': -1, 'female': 1})
  temp_features["Age"] = dataset.Age.fillna(dataset.Age.median())  
  
  # Fare min-max     
  #temp_features = pd.concat([temp_features,pd.get_dummies(temp_features['Pclass'])],axis=1)
                            
  d = temp_features["Pclass"] 
  temp_features["Pclass"] = (d - d.min()) / (d.max() - d.min())
    
  d = temp_features["SibSp"] 
  temp_features["SibSp"] = (d - d.min()) / (d.max() - d.min())
  # standard
  d = temp_features["Age"]   
  temp_features["Age"] = (d - d.mean()) / d.std()  

  d = temp_features["Fare"]       
  temp_features["Fare"] = (d - d.mean()) / d.std()      
  temp_features['FareWomen'] = temp_features['Sex'] * temp_features["Fare"] 
  #temp_features['FareWomen2'] = temp_features['Sex'] * temp_features["Pclass"]

  #d = temp_features["Parch"] 
  temp_features["Parch"] = d - d.min() / (d.max() - d.min())  
  
  temp_features['Embarked'] = temp_features['Embarked'].fillna('unknown')    
  temp_features = pd.concat([temp_features,pd.get_dummies(temp_features['Embarked'])],axis=1)
    
  del temp_features['Embarked']
  if('unknown' in temp_features.columns):
      del temp_features['unknown']    
  #display(temp_features)
  return temp_features

# class weight for imbalance
v = data_train['Survived'].value_counts()
#class_weight = {0:v[0]/(max(v[0],v[1])), 1:( v[1]/max(v[0],v[1]) )}
class_weight = {0:max(v[0],v[1])/v[0], 1:max(v[0],v[1])/v[1]}
model = make_pipeline(
    # <YOUR CODE>
    # E.g.        
    LogisticRegression(random_state=0,max_iter=1000, multi_class='multinomial',
                       class_weight=class_weight,
                       solver = 'saga', # work better for small dataset
                      penalty = 'l1')
)

# Validation code (do not touch)
data = pd.read_csv("train.csv", index_col='PassengerId')
data_train, data_test = train_test_split(data, test_size=200, random_state=42)

model.fit(
    feature_selection_and_preprocessing(
        data_train.drop('Survived', axis=1)
    ),
    data_train['Survived']
)

train_predictions = model.predict(
    feature_selection_and_preprocessing(
        data_train.drop('Survived', axis=1)
    )
)

test_predictions = model.predict(
    feature_selection_and_preprocessing(
        data_test.drop('Survived', axis=1)
    )
)

print("Train accuracy:", accuracy_score(
    data_train['Survived'],
    train_predictions
))
print("Test accuracy:", accuracy_score(
    data_test['Survived'],
    test_predictions
))
# Out:
# Train accuracy: 0.768451519536903
# Test accuracy: 0.84
